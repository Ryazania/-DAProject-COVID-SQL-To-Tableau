# %% [markdown]
# # Data Analyst Portfolio Project | SQL Data Exploration | Project 1/4

# %% [markdown]
# ### This is one of series of project in SQL Data Exploration where I am looking into Covid Death number globally. Data was taken from public website "Our Wold in Data".
#
# The death figures on a given date on this website do not necessarily show the number of new deaths on that day, but the deaths reported on that day. Since reporting is delayed and the levels of reporting can vary between days, such as on weekends, regardless of any actual variation of deaths, it is more helpful to view the seven-day rolling average of the daily figures as we do in the chart here.
#
#
# ![daily-new-confirmed-covid-19-deaths-per-million-people.png](attachment:8716b53a-a3f5-42c9-9243-d8e8a274b866.png)
#
#
#
# ###	1. Download the dataset
# https://ourworldindata.org/covid-deat
#
# Alternatively you could download from my github in the same folder as where you find this projecths

# %% [markdown]
# [external link text](http://ryazania.github.io)

# %% [markdown]
# Basically I cut the excel from column AA to the end ( CTRL + SHIFT + right arrow) and deleted in and saved it as CovidDeath.xls and from "Populations" column through Z columns as Vaccination.xls and joined them in later stage.
